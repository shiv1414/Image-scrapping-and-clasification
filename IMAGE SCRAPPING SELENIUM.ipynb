# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

import requests

import re

import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = "https://www.amazon.com/s?k=Saree&page=4&crid=3KN3NEAFCYLXI&qid=1668146019&sprefix=saree%2Caps%2C400&ref=sr_pg_4"
driver.get(url)

# %%
images_saree = []
start = 0
end = 4
for j in range(start,end):

    pro = driver.find_elements(By.XPATH,'//img[@class="s-image"]')
    try:
        for i in pro:
            images = i.get_attribute('src')
            images_saree.append(images)
        
        next_bu = driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[1]/div/span[1]/div[1]/div[67]/div/div/span/a[3]")
        
    except NoSuchElementException :
        names.append('NA')

# %%
for img in images_saree:
    file_nam = img.split('/')[-1]
    print(f"this is the file name:{file_nam}")
    r = requests.get(img,stream = True)
    if r.status_code ==200:
        with open(file_nam,'wb') as f:
            for chunk in r:
                f.write(chunk)
                
    else:
        print('')
# Out:
# this is the file name:71pZVzmBKaL._AC_UL320_.jpg
# this is the file name:71mS0rHP8zL._AC_UL320_.jpg
# this is the file name:81fFYpbEFBL._AC_UL320_.jpg
# this is the file name:612tDJQGntL._AC_UL320_.jpg
# this is the file name:31CP0eBkmjL._AC_UL320_.jpg
# this is the file name:71bHPi0MqpL._AC_UL320_.jpg
# this is the file name:61YnP5ho9gL._AC_UL320_.jpg
# this is the file name:81UYkQMBx0L._AC_UL320_.jpg
# this is the file name:91WL2pKUVgL._MCnd_AC_UL320_.jpg
# this is the file name:71jWzsrptNS._AC_UL320_.jpg
# this is the file name:91u8yZNAOtL._AC_UL320_.jpg
# this is the file name:91hEF5wznaL._AC_UL320_.jpg
# this is the file name:712h1oo0k9L._AC_UL320_.jpg
# this is the file name:71tHQSv2XEL._AC_UL320_.jpg
# this is the file name:71udsZv2DDL._AC_UL320_.jpg
# this is the file name:91TelLxvlPL._AC_UL320_.jpg
# this is the file name:71559IyeYsL._AC_UL320_.jpg
# this is the file name:81ZpN-3xhkL._AC_UL320_.jpg
# this is the file name:71t5lXgNrLL._AC_UL320_.jpg
# ...

# %%
len(images_saree)
# Out:
# 240

# %%
url = "https://www.amazon.com/s?k=trousers+for+men&page=4&crid=2W32Y0E1L2RIZ&qid=1668146931&sprefix=trouser%2Caps%2C412&ref=sr_pg_4"
driver.get(url)

# %%
images_trouser = []
start = 0
end = 4
for j in range(start,end):

    pro = driver.find_elements(By.XPATH,'//img[@class="s-image"]')
    try:
        for i in pro:
            image = i.get_attribute('src')
            images_trouser.append(image)
        
        next_bu = driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[1]/div/span[1]/div[1]/div[67]/div/div/span/a[3]")
        
    except NoSuchElementException :
        names.append('NA')

# %%
for imgs in images_trouser:
    file_names = imgs.split('/')[-1]
    print(f"this is the file name:{file_names}")
    r = requests.get(imgs,stream = True)
    if r.status_code ==200:
        with open(file_names,'wb') as f:
            for chunk in r:
                f.write(chunk)
                
    else:
        print('')
# Out:
# this is the file name:511Dj4fdGxL._AC_UL320_.jpg
# this is the file name:61nCop58zqL._AC_UL320_.jpg
# this is the file name:61Ll0RSQpxL._AC_UL320_.jpg
# this is the file name:51cprGxkVAL._AC_UL320_.jpg
# this is the file name:517y7U4O1VL._AC_UL320_.jpg
# this is the file name:61cIJjfWGCL._AC_UL320_.jpg
# this is the file name:61v5+gaxHgL._AC_UL320_.jpg
# this is the file name:511Dj4fdGxL._AC_UL320_.jpg
# this is the file name:51uD76OMWsL._AC_UL320_.jpg
# this is the file name:71yvaVLp4vL._AC_UL320_.jpg
# this is the file name:510mXFs05jL._AC_UL320_.jpg
# this is the file name:614mm7uTifL._AC_UL320_.jpg
# this is the file name:51eKeuYSkZL._AC_UL320_.jpg
# this is the file name:51Z+t9AKP8L._AC_UL320_.jpg
# this is the file name:7183ZnML-sL._AC_UL320_.jpg
# this is the file name:716mwcE39fL._AC_UL320_.jpg
# this is the file name:51RVbRsIN9L._AC_UL320_.jpg
# this is the file name:71GXSVDVgpL._AC_UL320_.jpg
# this is the file name:518YuN8y6qL._AC_UL320_.jpg
# ...

# %%
len(images_trouser)
# Out:
# 268

# %%
url = "https://www.amazon.com/s?k=jeans+for+men&page=4&crid=26AVVYYLFLTAZ&qid=1668155182&sprefix=jeans+for+%2Caps%2C519&ref=sr_pg_4"
driver.get(url)

# %%
images_jeans = []
start = 0
end = 4
for j in range(start,end):

    pro = driver.find_elements(By.XPATH,'//img[@class="s-image"]')
    try:
        for i in pro:
            imag = i.get_attribute('src')
            images_jeans.append(imag)
        
        next_bu = driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[1]/div/span[1]/div[1]/div[67]/div/div/span/a[3]")
        
    except NoSuchElementException :
        names.append('NA')

# %%
for im in images_jeans:
    file_namess = im.split('/')[-1]
    print(f"this is the file name:{file_namess}")
    r = requests.get(im,stream = True)
    if r.status_code ==200:
        with open(file_namess,'wb') as f:
            for chunk in r:
                f.write(chunk)
                
    else:
        print('')
# Out:
# this is the file name:71qlq+hdsLS._AC_UL320_.jpg
# this is the file name:811zfCn1guS._AC_UL320_.jpg
# this is the file name:81k9hOWgKpL._AC_UL320_.jpg
# this is the file name:7175cAcdZKL._AC_UL320_.jpg
# this is the file name:81YYE7RmEAL._AC_UL320_.jpg
# this is the file name:71vf05YHXuL._AC_UL320_.jpg
# this is the file name:71ALRKrEn2L._AC_UL320_.jpg
# this is the file name:61CvUAlvn-S._AC_UL320_.jpg
# this is the file name:8177OmYcxgL._AC_UL320_.jpg
# this is the file name:81ytbdwLZKL._AC_UL320_.jpg
# this is the file name:51gl10XhOyL._AC_UL320_.jpg
# this is the file name:61uDVgjVNBL._AC_UL320_.jpg
# this is the file name:71jVCIxWoHL._AC_UL320_.jpg
# this is the file name:717iw4zpw-L._AC_UL320_.jpg
# this is the file name:51Y2gyPl9zL._AC_UL320_.jpg
# this is the file name:61h2ocC7arL._AC_UL320_.jpg
# this is the file name:51N3xuMy2jL._AC_UL320_.jpg
# this is the file name:610q1nTQfhL._AC_UL320_.jpg
# this is the file name:51EYGpyKmTS._AC_UL320_.jpg
# ...

# %%
len(images_jeans)
# Out:
# 240
